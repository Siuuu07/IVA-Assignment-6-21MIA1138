# %% [markdown]
# # CSE4076
# # Image and Video Analytics
# # Assignment 6 - Task 2
#
# # Name: Mohamed Riyaz S
# # Reg No: 21MIA1138

# %% [markdown]
# # **Task 2: Strategic Marketing – Peak Shopping Duration**
#
# **Objective:**
# Analyze a video of a shopping area to identify the peak duration when the most people are shopping.
#
# **Task Description:**
#
# **Load Video:**
#
# Load the surveillance video from a shopping area.
#
# **People Detection:**
#
# Use frame differencing or optical flow to detect motion and identify people entering the frame.
# Count the number of people in each frame based on detected regions.
#
# **Peak Duration Identification:**
#
# Calculate the total number of people in the shopping area for each time period (e.g., 10-minute intervals).
# Plot the number of people over time and identify the time interval with the highest count of people.
#
# **Result:**
#
# Provide a summary of the peak shopping duration and display the corresponding frames from the video.

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the video
video_path = '/content/Task 2 Shopping.mp4'
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
else:
    print("Video loaded successfully.")

# Initialize background subtractor for people detection
back_sub = cv2.createBackgroundSubtractorMOG2()

# Parameters for peak duration identification
fps = cap.get(cv2.CAP_PROP_FPS)
interval_seconds = 60  # 1 minute for testing; adjust as needed for full video analysis
interval_frames = int(fps * interval_seconds)
current_interval_count = 0
people_counts = []

# Loop through video frames
frame_count = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break  # Exit loop if no frame is returned

    # Apply background subtraction
    fg_mask = back_sub.apply(frame)

    # Remove shadows and noise
    _, fg_mask = cv2.threshold(fg_mask, 200, 255, cv2.THRESH_BINARY)

    # Find contours of moving regions
    contours, _ = cv2.findContours(fg_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Count the number of detected people based on contours
    person_count = 0
    for contour in contours:
        if cv2.contourArea(contour) > 500:  # Minimum area to count as a person
            person_count += 1

    # Debugging: Print person count for each frame
    print(f"Frame {frame_count}: Detected people count = {person_count}")

    # Add to current interval count
    current_interval_count += person_count
    frame_count += 1

    # Check if interval duration has been reached
    if frame_count % interval_frames == 0:
        people_counts.append(current_interval_count)
        print(f"Interval {len(people_counts)}: Total people count = {current_interval_count}")
        current_interval_count = 0  # Reset count for the next interval

# Release video capture and clean up
cap.release()
cv2.destroyAllWindows()

# Check if people_counts is empty before calculating peak
if people_counts:
    # Identify the peak interval with the most people
    peak_interval = np.argmax(people_counts)
    peak_count = people_counts[peak_interval]
    print(f"Peak shopping duration at interval {peak_interval} with {peak_count} people.")

    # Plot the people count over intervals
    interval_times = [(i + 1) * interval_seconds / 60 for i in range(len(people_counts))]  # Convert seconds to minutes
    plt.figure(figsize=(12, 6))
    plt.plot(interval_times, people_counts, marker='o', linestyle='-', color='b')
    plt.xlabel("Time (minutes)")
    plt.ylabel("People Count")
    plt.title("People Count Over Time Intervals in Shopping Area")
    plt.grid(True)
    plt.show()
else:
    print("No people detected during the video.")
# Out:
# Video loaded successfully.
# Frame 0: Detected people count = 0
# Frame 1: Detected people count = 0
# Frame 2: Detected people count = 0
# Frame 3: Detected people count = 0
# Frame 4: Detected people count = 0
# Frame 5: Detected people count = 76
# Frame 6: Detected people count = 59
# Frame 7: Detected people count = 45
# Frame 8: Detected people count = 19
# Frame 9: Detected people count = 16
# Frame 10: Detected people count = 42
# Frame 11: Detected people count = 51
# Frame 12: Detected people count = 46
# Frame 13: Detected people count = 53
# Frame 14: Detected people count = 56
# Frame 15: Detected people count = 53
# Frame 16: Detected people count = 55
# Frame 17: Detected people count = 55
# Frame 18: Detected people count = 48
# Frame 19: Detected people count = 48
# Frame 20: Detected people count = 47
# Frame 21: Detected people count = 46
# Frame 22: Detected people count = 44
# Frame 23: Detected people count = 45
# Frame 24: Detected people count = 48
# Frame 25: Detected people count = 44
# Frame 26: Detected people count = 51
# Frame 27: Detected people count = 42
# Frame 28: Detected people count = 46
# Frame 29: Detected people count = 47
# Frame 30: Detected people count = 52
# Frame 31: Detected people count = 48
# Frame 32: Detected people count = 50
# Frame 33: Detected people count = 53
# Frame 34: Detected people count = 55
# Frame 35: Detected people count = 65
# Frame 36: Detected people count = 66
# Frame 37: Detected people count = 58
# Frame 38: Detected people count = 70
# Frame 39: Detected people count = 59
# Frame 40: Detected people count = 53
# Frame 41: Detected people count = 54
# Frame 42: Detected people count = 53
# Frame 43: Detected people count = 55
# Frame 44: Detected people count = 55
# Frame 45: Detected people count = 50
# Frame 46: Detected people count = 52
# Frame 47: Detected people count = 53
# Frame 48: Detected people count = 57
# Frame 49: Detected people count = 55
# Frame 50: Detected people count = 51
# Frame 51: Detected people count = 57
# Frame 52: Detected people count = 52
# Frame 53: Detected people count = 50
# Frame 54: Detected people count = 53
# Frame 55: Detected people count = 45
# Frame 56: Detected people count = 43
# Frame 57: Detected people count = 45
# Frame 58: Detected people count = 40
# Frame 59: Detected people count = 43
# Frame 60: Detected people count = 49
# Frame 61: Detected people count = 47
# Frame 62: Detected people count = 48
# Frame 63: Detected people count = 55
# Frame 64: Detected people count = 55
# Frame 65: Detected people count = 58
# Frame 66: Detected people count = 55
# Frame 67: Detected people count = 57
# Frame 68: Detected people count = 54
# Frame 69: Detected people count = 52
# Frame 70: Detected people count = 46
# Frame 71: Detected people count = 45
# Frame 72: Detected people count = 51
# Frame 73: Detected people count = 50
# Frame 74: Detected people count = 53
# Frame 75: Detected people count = 57
# Frame 76: Detected people count = 55
# Frame 77: Detected people count = 54
# Frame 78: Detected people count = 49
# Frame 79: Detected people count = 44
# Frame 80: Detected people count = 49
# Frame 81: Detected people count = 49
# Frame 82: Detected people count = 50
# Frame 83: Detected people count = 54
# Frame 84: Detected people count = 54
# Frame 85: Detected people count = 47
# Frame 86: Detected people count = 45
# Frame 87: Detected people count = 46
# Frame 88: Detected people count = 46
# Frame 89: Detected people count = 43
# Frame 90: Detected people count = 43
# Frame 91: Detected people count = 50
# Frame 92: Detected people count = 49
# Frame 93: Detected people count = 48
# Frame 94: Detected people count = 65
# Frame 95: Detected people count = 52
# Frame 96: Detected people count = 57
# Frame 97: Detected people count = 47
# Frame 98: Detected people count = 53
# Frame 99: Detected people count = 54
# Frame 100: Detected people count = 54
# Frame 101: Detected people count = 58
# Frame 102: Detected people count = 54
# Frame 103: Detected people count = 58
# Frame 104: Detected people count = 57
# Frame 105: Detected people count = 56
# Frame 106: Detected people count = 59
# Frame 107: Detected people count = 50
# Frame 108: Detected people count = 55
# Frame 109: Detected people count = 51
# Frame 110: Detected people count = 49
# Frame 111: Detected people count = 47
# Frame 112: Detected people count = 51
# Frame 113: Detected people count = 48
# Frame 114: Detected people count = 44
# Frame 115: Detected people count = 45
# Frame 116: Detected people count = 47
# Frame 117: Detected people count = 42
# Frame 118: Detected people count = 43
# Frame 119: Detected people count = 43
# Frame 120: Detected people count = 46
# Frame 121: Detected people count = 49
# Frame 122: Detected people count = 43
# Frame 123: Detected people count = 47
# Frame 124: Detected people count = 37
# Frame 125: Detected people count = 40
# Frame 126: Detected people count = 45
# Frame 127: Detected people count = 46
# Frame 128: Detected people count = 42
# Frame 129: Detected people count = 41
# Frame 130: Detected people count = 43
# Frame 131: Detected people count = 44
# Frame 132: Detected people count = 42
# Frame 133: Detected people count = 41
# Frame 134: Detected people count = 40
# Frame 135: Detected people count = 40
# Frame 136: Detected people count = 40
# Frame 137: Detected people count = 37
# Frame 138: Detected people count = 34
# Frame 139: Detected people count = 40
# Frame 140: Detected people count = 35
# Frame 141: Detected people count = 33
# Frame 142: Detected people count = 29
# Frame 143: Detected people count = 30
# Frame 144: Detected people count = 26
# Frame 145: Detected people count = 22
# Frame 146: Detected people count = 25
# Frame 147: Detected people count = 24
# Frame 148: Detected people count = 21
# Frame 149: Detected people count = 24
# Frame 150: Detected people count = 21
# Frame 151: Detected people count = 20
# Frame 152: Detected people count = 21
# Frame 153: Detected people count = 22
# Frame 154: Detected people count = 18
# Frame 155: Detected people count = 20
# Frame 156: Detected people count = 24
# Frame 157: Detected people count = 25
# Frame 158: Detected people count = 30
# Frame 159: Detected people count = 33
# Frame 160: Detected people count = 38
# Frame 161: Detected people count = 39
# Frame 162: Detected people count = 46
# Frame 163: Detected people count = 48
# Frame 164: Detected people count = 51
# Frame 165: Detected people count = 53
# Frame 166: Detected people count = 54
# Frame 167: Detected people count = 59
# Frame 168: Detected people count = 58
# Frame 169: Detected people count = 61
# Frame 170: Detected people count = 56
# Frame 171: Detected people count = 56
# Frame 172: Detected people count = 54
# Frame 173: Detected people count = 63
# Frame 174: Detected people count = 66
# Frame 175: Detected people count = 64
# Frame 176: Detected people count = 58
# Frame 177: Detected people count = 61
# Frame 178: Detected people count = 64
# Frame 179: Detected people count = 57
# Frame 180: Detected people count = 55
# Frame 181: Detected people count = 49
# Frame 182: Detected people count = 52
# Frame 183: Detected people count = 52
# Frame 184: Detected people count = 53
# Frame 185: Detected people count = 49
# Frame 186: Detected people count = 45
# Frame 187: Detected people count = 54
# Frame 188: Detected people count = 48
# Frame 189: Detected people count = 52
# Frame 190: Detected people count = 52
# Frame 191: Detected people count = 46
# Frame 192: Detected people count = 56
# Frame 193: Detected people count = 49
# Frame 194: Detected people count = 46
# Frame 195: Detected people count = 46
# Frame 196: Detected people count = 48
# Frame 197: Detected people count = 48
# Frame 198: Detected people count = 45
# Frame 199: Detected people count = 48
# Frame 200: Detected people count = 44
# Frame 201: Detected people count = 48
# Frame 202: Detected people count = 46
# Frame 203: Detected people count = 44
# Frame 204: Detected people count = 47
# Frame 205: Detected people count = 54
# Frame 206: Detected people count = 49
# Frame 207: Detected people count = 48
# Frame 208: Detected people count = 50
# Frame 209: Detected people count = 44
# Frame 210: Detected people count = 45
# Frame 211: Detected people count = 42
# Frame 212: Detected people count = 46
# Frame 213: Detected people count = 43
# Frame 214: Detected people count = 45
# Frame 215: Detected people count = 46
# Frame 216: Detected people count = 38
# Frame 217: Detected people count = 41
# Frame 218: Detected people count = 37
# Frame 219: Detected people count = 39
# Frame 220: Detected people count = 45
# Frame 221: Detected people count = 41
# Frame 222: Detected people count = 32
# Frame 223: Detected people count = 40
# Frame 224: Detected people count = 39
# Frame 225: Detected people count = 40
# Frame 226: Detected people count = 38
# Frame 227: Detected people count = 34
# Frame 228: Detected people count = 36
# Frame 229: Detected people count = 40
# Frame 230: Detected people count = 36
# Frame 231: Detected people count = 40
# Frame 232: Detected people count = 39
# Frame 233: Detected people count = 46
# Frame 234: Detected people count = 34
# Frame 235: Detected people count = 44
# Frame 236: Detected people count = 45
# Frame 237: Detected people count = 39
# Frame 238: Detected people count = 40
# Frame 239: Detected people count = 42
# Frame 240: Detected people count = 44
# Frame 241: Detected people count = 47
# Frame 242: Detected people count = 46
# Frame 243: Detected people count = 43
# Frame 244: Detected people count = 42
# Frame 245: Detected people count = 47
# Frame 246: Detected people count = 49
# Frame 247: Detected people count = 44
# Frame 248: Detected people count = 43
# Frame 249: Detected people count = 47
# Frame 250: Detected people count = 42
# Frame 251: Detected people count = 38
# Frame 252: Detected people count = 37
# Frame 253: Detected people count = 37
# Frame 254: Detected people count = 43
# Frame 255: Detected people count = 34
# Frame 256: Detected people count = 33
# Frame 257: Detected people count = 35
# Frame 258: Detected people count = 37
# Frame 259: Detected people count = 30
# Frame 260: Detected people count = 28
# Frame 261: Detected people count = 33
# Frame 262: Detected people count = 33
# Frame 263: Detected people count = 40
# Frame 264: Detected people count = 35
# Frame 265: Detected people count = 37
# Frame 266: Detected people count = 33
# Frame 267: Detected people count = 35
# Frame 268: Detected people count = 42
# Frame 269: Detected people count = 37
# Frame 270: Detected people count = 36
# Frame 271: Detected people count = 34
# Frame 272: Detected people count = 32
# Frame 273: Detected people count = 34
# Frame 274: Detected people count = 35
# Frame 275: Detected people count = 44
# Frame 276: Detected people count = 44
# Frame 277: Detected people count = 44
# Frame 278: Detected people count = 50
# Frame 279: Detected people count = 47
# Frame 280: Detected people count = 45
# Frame 281: Detected people count = 44
# Frame 282: Detected people count = 44
# Frame 283: Detected people count = 41
# Frame 284: Detected people count = 36
# Frame 285: Detected people count = 38
# Frame 286: Detected people count = 37
# Frame 287: Detected people count = 41
# Frame 288: Detected people count = 44
# Frame 289: Detected people count = 43
# Frame 290: Detected people count = 43
# Frame 291: Detected people count = 37
# Frame 292: Detected people count = 40
# Frame 293: Detected people count = 44
# Frame 294: Detected people count = 46
# Frame 295: Detected people count = 38
# Frame 296: Detected people count = 39
# Frame 297: Detected people count = 27
# Frame 298: Detected people count = 30
# Frame 299: Detected people count = 33
# No people detected during the video.
